# %%
# !pip install -q  torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate

import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from peft import LoraConfig
from trl import SFTTrainer
import matplotlib.pyplot as plt 
import numpy as np

# %%
from datasets import load_dataset
from datasets import load_dataset,Features,Value

ds = load_dataset("json",data_files="/home/ac.zyang/LLM/falcon/kbase_formatted_data.json", split='train',field='data')
# ds = ds.select(list(range(50)))
ds = ds.train_test_split(test_size=0.2)

# %%
def get_tuning_loss_plot(log_hist, graph_name):
    steps, train_loss, val_loss = [], [], []
    for i in range(len(log_hist)//2):
        steps.append(2*(i+1))
        train_loss.append(log_hist[2*i]['loss'])
        val_loss.append(log_hist[2*i+1]['eval_loss'])

    plt.plot(steps, train_loss, label = "train loss") 
    plt.plot(steps, val_loss, label = "validation loss") 
    plt.legend()
    plt.title("Model fine tune loss")
    plt.xlabel("steps")
    plt.ylabel("loss")
    plt.savefig(f"{graph_name}_tuning_loss.png")
    plt.show()

# %%
# Model and tokenizer names
base_model_name = "NousResearch/Llama-2-7b-chat-hf"
refined_model = "llama-2-7b-kbase-10-epochs-no-quant" #You can give it your own name

# Tokenizer
llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name, trust_remote_code=True)
llama_tokenizer.pad_token = llama_tokenizer.eos_token
llama_tokenizer.padding_side = "left"  # Fix for fp16

# Quantization Config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)

# Model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
#     quantization_config=quant_config,
    device_map="auto"
)
base_model.config.use_cache = False
base_model.config.pretraining_tp = 1
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/ac.zyang/miniconda3/envs/ke/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/ac.zyang/miniconda3/envs/ke/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=8,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "v_proj"]
)

# Training Params
train_params = TrainingArguments(
    output_dir="./results-10-epoches-no-quant",
    evaluation_strategy = "steps",
    num_train_epochs=10,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=25,
    logging_steps=10,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Trainer
trainer = SFTTrainer(
    model=base_model,
    train_dataset=ds['train'],
    eval_dataset=ds['test'],
    peft_config=peft_parameters,
    dataset_text_field="text",
    tokenizer=llama_tokenizer,
    args=train_params
)

# Training
trainer.train(resume_from_checkpoint=True)

# save model
trainer.save_model(refined_model)

# plot loss graph
get_tuning_loss_plot(trainer.state.log_history, refined_model)
# Out:
# /home/ac.zyang/miniconda3/envs/ke/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:166: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/2432 [00:00<?, ? examples/s]
# Map:   0%|          | 0/608 [00:00<?, ? examples/s]
# /home/ac.zyang/miniconda3/envs/ke/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:207: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='6080' max='6080' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6080/6080 6:34:49, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4330</td>
#       <td>0.644000</td>
#       <td>0.515666</td>
#     </tr>
#     <tr>
#       <td>4340</td>
#       <td>0.614200</td>
#       <td>0.519198</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.346800</td>
#       <td>0.524999</td>
#     </tr>
#     <tr>
#       <td>4360</td>
#       <td>0.525600</td>
#       <td>0.531819</td>
#     </tr>
#     <tr>
#       <td>4370</td>
#       <td>0.596600</td>
#       <td>0.522534</td>
#     </tr>
#     <tr>
#       <td>4380</td>
#       <td>0.544500</td>
#       <td>0.520260</td>
#     </tr>
#     <tr>
#       <td>4390</td>
#       <td>0.510600</td>
#       <td>0.520803</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.487700</td>
#       <td>0.528045</td>
#     </tr>
#     <tr>
#       <td>4410</td>
#       <td>0.483100</td>
#       <td>0.532812</td>
#     </tr>
#     <tr>
#       <td>4420</td>
#       <td>0.648100</td>
#       <td>0.524469</td>
#     </tr>
#     <tr>
#       <td>4430</td>
#       <td>0.550700</td>
#       <td>0.525540</td>
#     </tr>
#     <tr>
#       <td>4440</td>
#       <td>0.577700</td>
#       <td>0.527372</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>0.553100</td>
#       <td>0.539494</td>
#     </tr>
#     <tr>
#       <td>4460</td>
#       <td>0.658100</td>
#       <td>0.542065</td>
#     </tr>
#     <tr>
#       <td>4470</td>
#       <td>0.653800</td>
#       <td>0.533805</td>
#     </tr>
#     <tr>
#       <td>4480</td>
#       <td>0.491400</td>
#       <td>0.529640</td>
#     </tr>
#     <tr>
#       <td>4490</td>
#       <td>0.496000</td>
#       <td>0.534364</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.464700</td>
#       <td>0.544874</td>
#     </tr>
#     <tr>
#       <td>4510</td>
#       <td>0.587300</td>
#       <td>0.546251</td>
#     </tr>
#     <tr>
#       <td>4520</td>
#       <td>0.618600</td>
#       <td>0.533437</td>
#     </tr>
#     <tr>
#       <td>4530</td>
#       <td>0.474300</td>
#       <td>0.530868</td>
#     </tr>
#     <tr>
#       <td>4540</td>
#       <td>0.580000</td>
#       <td>0.528436</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>0.473400</td>
#       <td>0.533614</td>
#     </tr>
#     <tr>
#       <td>4560</td>
#       <td>0.543100</td>
#       <td>0.542917</td>
#     </tr>
#     <tr>
#       <td>4570</td>
#       <td>0.522600</td>
#       <td>0.534754</td>
#     </tr>
#     <tr>
#       <td>4580</td>
#       <td>0.513700</td>
#       <td>0.534727</td>
#     </tr>
#     <tr>
#       <td>4590</td>
#       <td>0.520900</td>
#       <td>0.535545</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.508900</td>
#       <td>0.543312</td>
#     </tr>
#     <tr>
#       <td>4610</td>
#       <td>0.427300</td>
#       <td>0.551540</td>
#     </tr>
#     <tr>
#       <td>4620</td>
#       <td>0.624400</td>
#       <td>0.541837</td>
#     </tr>
#     <tr>
#       <td>4630</td>
#       <td>0.477600</td>
#       <td>0.539530</td>
#     </tr>
#     <tr>
#       <td>4640</td>
#       <td>0.574800</td>
#       <td>0.537836</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>0.466700</td>
#       <td>0.544414</td>
#     </tr>
#     <tr>
#       <td>4660</td>
#       <td>0.574600</td>
#       <td>0.549712</td>
#     </tr>
#     <tr>
#       <td>4670</td>
#       <td>0.541700</td>
#       <td>0.543103</td>
#     </tr>
#     <tr>
#       <td>4680</td>
#       <td>0.547700</td>
#       <td>0.543016</td>
#     </tr>
#     <tr>
#       <td>4690</td>
#       <td>0.552300</td>
#       <td>0.541716</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.469700</td>
#       <td>0.549203</td>
#     </tr>
#     <tr>
#       <td>4710</td>
#       <td>0.631900</td>
#       <td>0.553270</td>
#     </tr>
#     <tr>
#       <td>4720</td>
#       <td>0.607400</td>
#       <td>0.548709</td>
#     </tr>
#     <tr>
#       <td>4730</td>
#       <td>0.485800</td>
#       <td>0.543696</td>
#     </tr>
#     <tr>
#       <td>4740</td>
#       <td>0.439600</td>
#       <td>0.541475</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.366800</td>
#       <td>0.547446</td>
#     </tr>
#     <tr>
#       <td>4760</td>
#       <td>0.515300</td>
#       <td>0.553625</td>
#     </tr>
#     <tr>
#       <td>4770</td>
#       <td>0.623100</td>
#       <td>0.545564</td>
#     </tr>
#     <tr>
#       <td>4780</td>
#       <td>0.571500</td>
#       <td>0.544615</td>
#     </tr>
#     <tr>
#       <td>4790</td>
#       <td>0.531200</td>
#       <td>0.542696</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.442000</td>
#       <td>0.550554</td>
#     </tr>
#     <tr>
#       <td>4810</td>
#       <td>0.453500</td>
#       <td>0.560815</td>
#     </tr>
#     <tr>
#       <td>4820</td>
#       <td>0.553800</td>
#       <td>0.553981</td>
#     </tr>
#     <tr>
#       <td>4830</td>
#       <td>0.490000</td>
#       <td>0.550540</td>
#     </tr>
#     <tr>
#       <td>4840</td>
#       <td>0.578100</td>
#       <td>0.546003</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>0.586800</td>
#       <td>0.555638</td>
#     </tr>
#     <tr>
#       <td>4860</td>
#       <td>0.437600</td>
#       <td>0.554628</td>
#     </tr>
#     <tr>
#       <td>4870</td>
#       <td>0.444800</td>
#       <td>0.561481</td>
#     </tr>
#     <tr>
#       <td>4880</td>
#       <td>0.372900</td>
#       <td>0.564185</td>
#     </tr>
#     <tr>
#       <td>4890</td>
#       <td>0.430900</td>
#       <td>0.557152</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.381500</td>
#       <td>0.555630</td>
#     </tr>
#     <tr>
#       <td>4910</td>
#       <td>0.378300</td>
#       <td>0.570347</td>
#     </tr>
#     <tr>
#       <td>4920</td>
#       <td>0.428000</td>
#       <td>0.571552</td>
#     </tr>
#     <tr>
#       <td>4930</td>
#       <td>0.444200</td>
#       <td>0.559606</td>
#     </tr>
#     <tr>
#       <td>4940</td>
#       <td>0.418100</td>
#       <td>0.565036</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>0.412900</td>
#       <td>0.562301</td>
#     </tr>
#     <tr>
#       <td>4960</td>
#       <td>0.358700</td>
#       <td>0.571765</td>
#     </tr>
#     <tr>
#       <td>4970</td>
#       <td>0.505000</td>
#       <td>0.567664</td>
#     </tr>
#     <tr>
#       <td>4980</td>
#       <td>0.490600</td>
#       <td>0.558121</td>
#     </tr>
#     <tr>
#       <td>4990</td>
#       <td>0.378600</td>
#       <td>0.560587</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.498200</td>
#       <td>0.559242</td>
#     </tr>
#     <tr>
#       <td>5010</td>
#       <td>0.368100</td>
#       <td>0.563783</td>
#     </tr>
#     <tr>
#       <td>5020</td>
#       <td>0.426800</td>
#       <td>0.575137</td>
#     </tr>
#     <tr>
#       <td>5030</td>
#       <td>0.432500</td>
#       <td>0.567886</td>
#     </tr>
#     <tr>
#       <td>5040</td>
#       <td>0.381500</td>
#       <td>0.568739</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>0.423900</td>
#       <td>0.561067</td>
#     </tr>
#     <tr>
#       <td>5060</td>
#       <td>0.361900</td>
#       <td>0.575424</td>
#     </tr>
#     <tr>
#       <td>5070</td>
#       <td>0.424100</td>
#       <td>0.587972</td>
#     </tr>
#     <tr>
#       <td>5080</td>
#       <td>0.440100</td>
#       <td>0.566510</td>
#     </tr>
#     <tr>
#       <td>5090</td>
#       <td>0.381900</td>
#       <td>0.575141</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.394200</td>
#       <td>0.571795</td>
#     </tr>
#     <tr>
#       <td>5110</td>
#       <td>0.343200</td>
#       <td>0.583206</td>
#     </tr>
#     <tr>
#       <td>5120</td>
#       <td>0.484800</td>
#       <td>0.582984</td>
#     </tr>
#     <tr>
#       <td>5130</td>
#       <td>0.490300</td>
#       <td>0.571554</td>
#     </tr>
#     <tr>
#       <td>5140</td>
#       <td>0.364100</td>
#       <td>0.571225</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>0.397700</td>
#       <td>0.569446</td>
#     </tr>
#     <tr>
#       <td>5160</td>
#       <td>0.427600</td>
#       <td>0.575955</td>
#     </tr>
#     <tr>
#       <td>5170</td>
#       <td>0.477900</td>
#       <td>0.580227</td>
#     </tr>
#     <tr>
#       <td>5180</td>
#       <td>0.528800</td>
#       <td>0.573720</td>
#     </tr>
#     <tr>
#       <td>5190</td>
#       <td>0.348900</td>
#       <td>0.574950</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.379700</td>

# %%
trainer.state.log_history
# Out:
# [{'epoch': 0.02, 'learning_rate': 0.0002, 'loss': 1.5909, 'step': 10},
#  {'epoch': 0.02,
#   'eval_loss': 1.8990402221679688,
#   'eval_runtime': 166.8807,
#   'eval_samples_per_second': 3.643,
#   'eval_steps_per_second': 0.455,
#   'step': 10},
#  {'epoch': 0.03, 'learning_rate': 0.0002, 'loss': 1.7702, 'step': 20},
#  {'epoch': 0.03,
#   'eval_loss': 1.6708383560180664,
#   'eval_runtime': 161.383,
#   'eval_samples_per_second': 3.767,
#   'eval_steps_per_second': 0.471,
#   'step': 20},
#  {'epoch': 0.05, 'learning_rate': 0.0002, 'loss': 1.786, 'step': 30},
#  {'epoch': 0.05,
#   'eval_loss': 1.5604145526885986,
#   'eval_runtime': 138.1666,
#   'eval_samples_per_second': 4.4,
#   'eval_steps_per_second': 0.55,
#   'step': 30},
#  {'epoch': 0.07, 'learning_rate': 0.0002, 'loss': 1.6937, 'step': 40},
#  {'epoch': 0.07,
#   'eval_loss': 1.4918292760849,
#   'eval_runtime': 134.4272,
#   'eval_samples_per_second': 4.523,
#   'eval_steps_per_second': 0.565,
#   'step': 40},
#  {'epoch': 0.08, 'learning_rate': 0.0002, 'loss': 1.5974, 'step': 50},
#  {'epoch': 0.08,
#   'eval_loss': 1.424523949623108,
#   'eval_runtime': 138.749,
#   'eval_samples_per_second': 4.382,
#   'eval_steps_per_second': 0.548,
#   'step': 50},
#  {'epoch': 0.1, 'learning_rate': 0.0002, 'loss': 1.2673, 'step': 60},
#  {'epoch': 0.1,
#   'eval_loss': 1.4009246826171875,
#   'eval_runtime': 132.8699,
#   'eval_samples_per_second': 4.576,
#   'eval_steps_per_second': 0.572,
#   'step': 60},
#  {'epoch': 0.12, 'learning_rate': 0.0002, 'loss': 1.4049, 'step': 70},
#  {'epoch': 0.12,
#   'eval_loss': 1.3794933557510376,
#   'eval_runtime': 132.7804,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 70},
#  {'epoch': 0.13, 'learning_rate': 0.0002, 'loss': 1.4561, 'step': 80},
#  {'epoch': 0.13,
#   'eval_loss': 1.3647637367248535,
#   'eval_runtime': 132.7554,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 80},
#  {'epoch': 0.15, 'learning_rate': 0.0002, 'loss': 1.4685, 'step': 90},
#  {'epoch': 0.15,
#   'eval_loss': 1.3604134321212769,
#   'eval_runtime': 132.783,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 90},
#  {'epoch': 0.16, 'learning_rate': 0.0002, 'loss': 1.4267, 'step': 100},
#  {'epoch': 0.16,
#   'eval_loss': 1.3609908819198608,
#   'eval_runtime': 132.9105,
#   'eval_samples_per_second': 4.575,
#   'eval_steps_per_second': 0.572,
#   'step': 100},
#  {'epoch': 0.18, 'learning_rate': 0.0002, 'loss': 1.198, 'step': 110},
#  {'epoch': 0.18,
#   'eval_loss': 1.3467320203781128,
#   'eval_runtime': 132.7926,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 110},
#  {'epoch': 0.2, 'learning_rate': 0.0002, 'loss': 1.3813, 'step': 120},
#  {'epoch': 0.2,
#   'eval_loss': 1.3383114337921143,
#   'eval_runtime': 132.7297,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 120},
#  {'epoch': 0.21, 'learning_rate': 0.0002, 'loss': 1.4644, 'step': 130},
#  {'epoch': 0.21,
#   'eval_loss': 1.3222891092300415,
#   'eval_runtime': 132.7495,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 130},
#  {'epoch': 0.23, 'learning_rate': 0.0002, 'loss': 1.3775, 'step': 140},
#  {'epoch': 0.23,
#   'eval_loss': 1.3189706802368164,
#   'eval_runtime': 132.7499,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 140},
#  {'epoch': 0.25, 'learning_rate': 0.0002, 'loss': 1.2793, 'step': 150},
#  {'epoch': 0.25,
#   'eval_loss': 1.3290680646896362,
#   'eval_runtime': 132.8081,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 150},
#  {'epoch': 0.26, 'learning_rate': 0.0002, 'loss': 1.3022, 'step': 160},
#  {'epoch': 0.26,
#   'eval_loss': 1.2980217933654785,
#   'eval_runtime': 132.7491,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 160},
#  {'epoch': 0.28, 'learning_rate': 0.0002, 'loss': 1.3315, 'step': 170},
#  {'epoch': 0.28,
#   'eval_loss': 1.290795922279358,
#   'eval_runtime': 132.6542,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 170},
#  {'epoch': 0.3, 'learning_rate': 0.0002, 'loss': 1.3838, 'step': 180},
#  {'epoch': 0.3,
#   'eval_loss': 1.2825229167938232,
#   'eval_runtime': 132.8913,
#   'eval_samples_per_second': 4.575,
#   'eval_steps_per_second': 0.572,
#   'step': 180},
#  {'epoch': 0.31, 'learning_rate': 0.0002, 'loss': 1.3709, 'step': 190},
#  {'epoch': 0.31,
#   'eval_loss': 1.2850078344345093,
#   'eval_runtime': 132.9319,
#   'eval_samples_per_second': 4.574,
#   'eval_steps_per_second': 0.572,
#   'step': 190},
#  {'epoch': 0.33, 'learning_rate': 0.0002, 'loss': 1.1087, 'step': 200},
#  {'epoch': 0.33,
#   'eval_loss': 1.2615526914596558,
#   'eval_runtime': 132.8591,
#   'eval_samples_per_second': 4.576,
#   'eval_steps_per_second': 0.572,
#   'step': 200},
#  {'epoch': 0.35, 'learning_rate': 0.0002, 'loss': 1.2236, 'step': 210},
#  {'epoch': 0.35,
#   'eval_loss': 1.240464448928833,
#   'eval_runtime': 132.7504,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 210},
#  {'epoch': 0.36, 'learning_rate': 0.0002, 'loss': 1.3544, 'step': 220},
#  {'epoch': 0.36,
#   'eval_loss': 1.2353410720825195,
#   'eval_runtime': 132.7805,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 220},
#  {'epoch': 0.38, 'learning_rate': 0.0002, 'loss': 1.3293, 'step': 230},
#  {'epoch': 0.38,
#   'eval_loss': 1.2311664819717407,
#   'eval_runtime': 132.654,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 230},
#  {'epoch': 0.39, 'learning_rate': 0.0002, 'loss': 1.2394, 'step': 240},
#  {'epoch': 0.39,
#   'eval_loss': 1.2352190017700195,
#   'eval_runtime': 132.6882,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 240},
#  {'epoch': 0.41, 'learning_rate': 0.0002, 'loss': 1.0137, 'step': 250},
#  {'epoch': 0.41,
#   'eval_loss': 1.2427561283111572,
#   'eval_runtime': 132.7374,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 250},
#  {'epoch': 0.43, 'learning_rate': 0.0002, 'loss': 1.2459, 'step': 260},
#  {'epoch': 0.43,
#   'eval_loss': 1.228301763534546,
#   'eval_runtime': 132.7577,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 260},
#  {'epoch': 0.44, 'learning_rate': 0.0002, 'loss': 1.28, 'step': 270},
#  {'epoch': 0.44,
#   'eval_loss': 1.2178233861923218,
#   'eval_runtime': 132.7011,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 270},
#  {'epoch': 0.46, 'learning_rate': 0.0002, 'loss': 1.3197, 'step': 280},
#  {'epoch': 0.46,
#   'eval_loss': 1.2146350145339966,
#   'eval_runtime': 132.6919,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 280},
#  {'epoch': 0.48, 'learning_rate': 0.0002, 'loss': 1.3198, 'step': 290},
#  {'epoch': 0.48,
#   'eval_loss': 1.2135834693908691,
#   'eval_runtime': 132.7812,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 290},
#  {'epoch': 0.49, 'learning_rate': 0.0002, 'loss': 1.0581, 'step': 300},
#  {'epoch': 0.49,
#   'eval_loss': 1.221397042274475,
#   'eval_runtime': 132.7623,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 300},
#  {'epoch': 0.51, 'learning_rate': 0.0002, 'loss': 1.2061, 'step': 310},
#  {'epoch': 0.51,
#   'eval_loss': 1.2140071392059326,
#   'eval_runtime': 132.7312,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 310},
#  {'epoch': 0.53, 'learning_rate': 0.0002, 'loss': 1.279, 'step': 320},
#  {'epoch': 0.53,
#   'eval_loss': 1.2072210311889648,
#   'eval_runtime': 132.8408,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 320},
#  {'epoch': 0.54, 'learning_rate': 0.0002, 'loss': 1.285, 'step': 330},
#  {'epoch': 0.54,
#   'eval_loss': 1.2024359703063965,
#   'eval_runtime': 132.6823,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 330},
#  {'epoch': 0.56, 'learning_rate': 0.0002, 'loss': 1.275, 'step': 340},
#  {'epoch': 0.56,
#   'eval_loss': 1.2027517557144165,
#   'eval_runtime': 132.7304,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 340},
#  {'epoch': 0.58, 'learning_rate': 0.0002, 'loss': 1.0052, 'step': 350},
#  {'epoch': 0.58,
#   'eval_loss': 1.211054801940918,
#   'eval_runtime': 132.833,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 350},
#  {'epoch': 0.59, 'learning_rate': 0.0002, 'loss': 1.1343, 'step': 360},
#  {'epoch': 0.59,
#   'eval_loss': 1.1978683471679688,
#   'eval_runtime': 132.7416,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 360},
#  {'epoch': 0.61, 'learning_rate': 0.0002, 'loss': 1.273, 'step': 370},
#  {'epoch': 0.61,
#   'eval_loss': 1.1917287111282349,
#   'eval_runtime': 132.7854,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 370},
#  {'epoch': 0.62, 'learning_rate': 0.0002, 'loss': 1.1547, 'step': 380},
#  {'epoch': 0.62,
#   'eval_loss': 1.1909619569778442,
#   'eval_runtime': 132.7265,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 380},
#  {'epoch': 0.64, 'learning_rate': 0.0002, 'loss': 1.2171, 'step': 390},
#  {'epoch': 0.64,
#   'eval_loss': 1.1895647048950195,
#   'eval_runtime': 132.6902,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 390},
#  {'epoch': 0.66, 'learning_rate': 0.0002, 'loss': 1.0532, 'step': 400},
#  {'epoch': 0.66,
#   'eval_loss': 1.1971989870071411,
#   'eval_runtime': 132.8611,
#   'eval_samples_per_second': 4.576,
#   'eval_steps_per_second': 0.572,
#   'step': 400},
#  {'epoch': 0.67, 'learning_rate': 0.0002, 'loss': 1.2303, 'step': 410},
#  {'epoch': 0.67,
#   'eval_loss': 1.1899664402008057,
#   'eval_runtime': 132.7078,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 410},
#  {'epoch': 0.69, 'learning_rate': 0.0002, 'loss': 1.263, 'step': 420},
#  {'epoch': 0.69,
#   'eval_loss': 1.1861536502838135,
#   'eval_runtime': 132.6629,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 420},
#  {'epoch': 0.71, 'learning_rate': 0.0002, 'loss': 1.2963, 'step': 430},
#  {'epoch': 0.71,
#   'eval_loss': 1.179397463798523,
#   'eval_runtime': 132.7822,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 430},
#  {'epoch': 0.72, 'learning_rate': 0.0002, 'loss': 1.2053, 'step': 440},
#  {'epoch': 0.72,
#   'eval_loss': 1.1762924194335938,
#   'eval_runtime': 132.7489,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 440},
#  {'epoch': 0.74, 'learning_rate': 0.0002, 'loss': 1.0487, 'step': 450},
#  {'epoch': 0.74,
#   'eval_loss': 1.1850274801254272,
#   'eval_runtime': 132.7803,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 450},
#  {'epoch': 0.76, 'learning_rate': 0.0002, 'loss': 1.0663, 'step': 460},
#  {'epoch': 0.76,
#   'eval_loss': 1.180041790008545,
#   'eval_runtime': 132.7667,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 460},
#  {'epoch': 0.77, 'learning_rate': 0.0002, 'loss': 1.2215, 'step': 470},
#  {'epoch': 0.77,
#   'eval_loss': 1.175540566444397,
#   'eval_runtime': 132.7179,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 470},
#  {'epoch': 0.79, 'learning_rate': 0.0002, 'loss': 1.1707, 'step': 480},
#  {'epoch': 0.79,
#   'eval_loss': 1.1709963083267212,
#   'eval_runtime': 132.8195,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 480},
#  {'epoch': 0.81, 'learning_rate': 0.0002, 'loss': 1.2236, 'step': 490},
#  {'epoch': 0.81,
#   'eval_loss': 1.1695817708969116,
#   'eval_runtime': 132.7336,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 490},
#  {'epoch': 0.82, 'learning_rate': 0.0002, 'loss': 0.9181, 'step': 500},
#  {'epoch': 0.82,
#   'eval_loss': 1.1761709451675415,
#   'eval_runtime': 132.8818,
#   'eval_samples_per_second': 4.575,
#   'eval_steps_per_second': 0.572,
#   'step': 500},
#  {'epoch': 0.84, 'learning_rate': 0.0002, 'loss': 1.0778, 'step': 510},
#  {'epoch': 0.84,
#   'eval_loss': 1.1719681024551392,
#   'eval_runtime': 132.6701,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 510},
#  {'epoch': 0.86, 'learning_rate': 0.0002, 'loss': 1.2953, 'step': 520},
#  {'epoch': 0.86,
#   'eval_loss': 1.1676702499389648,
#   'eval_runtime': 132.7251,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 520},
#  {'epoch': 0.87, 'learning_rate': 0.0002, 'loss': 1.2243, 'step': 530},
#  {'epoch': 0.87,
#   'eval_loss': 1.1645305156707764,
#   'eval_runtime': 132.7155,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 530},
#  {'epoch': 0.89, 'learning_rate': 0.0002, 'loss': 1.1317, 'step': 540},
#  {'epoch': 0.89,
#   'eval_loss': 1.167576789855957,
#   'eval_runtime': 132.8436,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 540},
#  {'epoch': 0.9, 'learning_rate': 0.0002, 'loss': 1.0927, 'step': 550},
#  {'epoch': 0.9,
#   'eval_loss': 1.1725906133651733,
#   'eval_runtime': 132.9358,
#   'eval_samples_per_second': 4.574,
#   'eval_steps_per_second': 0.572,
#   'step': 550},
#  {'epoch': 0.92, 'learning_rate': 0.0002, 'loss': 1.157, 'step': 560},
#  {'epoch': 0.92,
#   'eval_loss': 1.1652992963790894,
#   'eval_runtime': 132.7388,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 560},
#  {'epoch': 0.94, 'learning_rate': 0.0002, 'loss': 1.2264, 'step': 570},
#  {'epoch': 0.94,
#   'eval_loss': 1.1610924005508423,
#   'eval_runtime': 132.8068,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 570},
#  {'epoch': 0.95, 'learning_rate': 0.0002, 'loss': 1.249, 'step': 580},
#  {'epoch': 0.95,
#   'eval_loss': 1.157673716545105,
#   'eval_runtime': 132.7656,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 580},
#  {'epoch': 0.97, 'learning_rate': 0.0002, 'loss': 1.1393, 'step': 590},
#  {'epoch': 0.97,
#   'eval_loss': 1.1550630331039429,
#   'eval_runtime': 132.6962,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 590},
#  {'epoch': 0.99, 'learning_rate': 0.0002, 'loss': 1.0098, 'step': 600},
#  {'epoch': 0.99,
#   'eval_loss': 1.1609104871749878,
#   'eval_runtime': 132.8405,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 600},
#  {'epoch': 1.0, 'learning_rate': 0.0002, 'loss': 1.1458, 'step': 610},
#  {'epoch': 1.0,
#   'eval_loss': 1.157738447189331,
#   'eval_runtime': 132.8084,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 610},
#  {'epoch': 1.02, 'learning_rate': 0.0002, 'loss': 1.0708, 'step': 620},
#  {'epoch': 1.02,
#   'eval_loss': 1.1492146253585815,
#   'eval_runtime': 132.8187,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 620},
#  {'epoch': 1.04, 'learning_rate': 0.0002, 'loss': 1.1509, 'step': 630},
#  {'epoch': 1.04,
#   'eval_loss': 1.1498632431030273,
#   'eval_runtime': 132.6863,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 630},
#  {'epoch': 1.05, 'learning_rate': 0.0002, 'loss': 1.0755, 'step': 640},
#  {'epoch': 1.05,
#   'eval_loss': 1.1507108211517334,
#   'eval_runtime': 132.6732,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 640},
#  {'epoch': 1.07, 'learning_rate': 0.0002, 'loss': 1.1391, 'step': 650},
#  {'epoch': 1.07,
#   'eval_loss': 1.152705192565918,
#   'eval_runtime': 132.8097,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 650},
#  {'epoch': 1.09, 'learning_rate': 0.0002, 'loss': 0.8834, 'step': 660},
#  {'epoch': 1.09,
#   'eval_loss': 1.1584888696670532,
#   'eval_runtime': 132.7381,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 660},
#  {'epoch': 1.1, 'learning_rate': 0.0002, 'loss': 1.1674, 'step': 670},
#  {'epoch': 1.1,
#   'eval_loss': 1.1516133546829224,
#   'eval_runtime': 132.7767,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 670},
#  {'epoch': 1.12, 'learning_rate': 0.0002, 'loss': 1.0869, 'step': 680},
#  {'epoch': 1.12,
#   'eval_loss': 1.1464929580688477,
#   'eval_runtime': 132.9124,
#   'eval_samples_per_second': 4.574,
#   'eval_steps_per_second': 0.572,
#   'step': 680},
#  {'epoch': 1.13, 'learning_rate': 0.0002, 'loss': 1.0942, 'step': 690},
#  {'epoch': 1.13,
#   'eval_loss': 1.1478896141052246,
#   'eval_runtime': 132.7915,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 690},
#  {'epoch': 1.15, 'learning_rate': 0.0002, 'loss': 0.9801, 'step': 700},
#  {'epoch': 1.15,
#   'eval_loss': 1.1469507217407227,
#   'eval_runtime': 132.9302,
#   'eval_samples_per_second': 4.574,
#   'eval_steps_per_second': 0.572,
#   'step': 700},
#  {'epoch': 1.17, 'learning_rate': 0.0002, 'loss': 0.8755, 'step': 710},
#  {'epoch': 1.17,
#   'eval_loss': 1.1527624130249023,
#   'eval_runtime': 132.7955,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 710},
#  {'epoch': 1.18, 'learning_rate': 0.0002, 'loss': 1.0476, 'step': 720},
#  {'epoch': 1.18,
#   'eval_loss': 1.1447397470474243,
#   'eval_runtime': 132.7212,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 720},
#  {'epoch': 1.2, 'learning_rate': 0.0002, 'loss': 1.0797, 'step': 730},
#  {'epoch': 1.2,
#   'eval_loss': 1.1417557001113892,
#   'eval_runtime': 132.7481,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 730},
#  {'epoch': 1.22, 'learning_rate': 0.0002, 'loss': 1.1064, 'step': 740},
#  {'epoch': 1.22,
#   'eval_loss': 1.1392405033111572,
#   'eval_runtime': 132.6796,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 740},
#  {'epoch': 1.23, 'learning_rate': 0.0002, 'loss': 1.0126, 'step': 750},
#  {'epoch': 1.23,
#   'eval_loss': 1.143692970275879,
#   'eval_runtime': 132.6888,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 750},
#  {'epoch': 1.25, 'learning_rate': 0.0002, 'loss': 0.8885, 'step': 760},
#  {'epoch': 1.25,
#   'eval_loss': 1.1621067523956299,
#   'eval_runtime': 132.6922,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 760},
#  {'epoch': 1.27, 'learning_rate': 0.0002, 'loss': 1.1071, 'step': 770},
#  {'epoch': 1.27,
#   'eval_loss': 1.143388032913208,
#   'eval_runtime': 132.7332,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 770},
#  {'epoch': 1.28, 'learning_rate': 0.0002, 'loss': 1.1879, 'step': 780},
#  {'epoch': 1.28,
#   'eval_loss': 1.1400631666183472,
#   'eval_runtime': 132.5977,
#   'eval_samples_per_second': 4.585,
#   'eval_steps_per_second': 0.573,
#   'step': 780},
#  {'epoch': 1.3, 'learning_rate': 0.0002, 'loss': 1.116, 'step': 790},
#  {'epoch': 1.3,
#   'eval_loss': 1.1395164728164673,
#   'eval_runtime': 132.636,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 790},
#  {'epoch': 1.32, 'learning_rate': 0.0002, 'loss': 0.9592, 'step': 800},
#  {'epoch': 1.32,
#   'eval_loss': 1.1400352716445923,
#   'eval_runtime': 132.6781,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 800},
#  {'epoch': 1.33, 'learning_rate': 0.0002, 'loss': 0.8614, 'step': 810},
#  {'epoch': 1.33,
#   'eval_loss': 1.1487740278244019,
#   'eval_runtime': 132.6237,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 810},
#  {'epoch': 1.35, 'learning_rate': 0.0002, 'loss': 1.0595, 'step': 820},
#  {'epoch': 1.35,
#   'eval_loss': 1.1410304307937622,
#   'eval_runtime': 132.6617,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 820},
#  {'epoch': 1.37, 'learning_rate': 0.0002, 'loss': 1.1136, 'step': 830},
#  {'epoch': 1.37,
#   'eval_loss': 1.1308344602584839,
#   'eval_runtime': 132.7216,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 830},
#  {'epoch': 1.38, 'learning_rate': 0.0002, 'loss': 1.0831, 'step': 840},
#  {'epoch': 1.38,
#   'eval_loss': 1.1282907724380493,
#   'eval_runtime': 132.7493,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 840},
#  {'epoch': 1.4, 'learning_rate': 0.0002, 'loss': 1.0218, 'step': 850},
#  {'epoch': 1.4,
#   'eval_loss': 1.130858063697815,
#   'eval_runtime': 132.7572,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 850},
#  {'epoch': 1.41, 'learning_rate': 0.0002, 'loss': 0.8467, 'step': 860},
#  {'epoch': 1.41,
#   'eval_loss': 1.1443865299224854,
#   'eval_runtime': 132.701,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 860},
#  {'epoch': 1.43, 'learning_rate': 0.0002, 'loss': 1.0659, 'step': 870},
#  {'epoch': 1.43,
#   'eval_loss': 1.1328884363174438,
#   'eval_runtime': 132.7589,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 870},
#  {'epoch': 1.45, 'learning_rate': 0.0002, 'loss': 1.1426, 'step': 880},
#  {'epoch': 1.45,
#   'eval_loss': 1.1255120038986206,
#   'eval_runtime': 132.6463,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 880},
#  {'epoch': 1.46, 'learning_rate': 0.0002, 'loss': 1.1334, 'step': 890},
#  {'epoch': 1.46,
#   'eval_loss': 1.1279031038284302,
#   'eval_runtime': 132.8787,
#   'eval_samples_per_second': 4.576,
#   'eval_steps_per_second': 0.572,
#   'step': 890},
#  {'epoch': 1.48, 'learning_rate': 0.0002, 'loss': 1.0289, 'step': 900},
#  {'epoch': 1.48,
#   'eval_loss': 1.1333814859390259,
#   'eval_runtime': 132.8552,
#   'eval_samples_per_second': 4.576,
#   'eval_steps_per_second': 0.572,
#   'step': 900},
#  {'epoch': 1.5, 'learning_rate': 0.0002, 'loss': 0.8521, 'step': 910},
#  {'epoch': 1.5,
#   'eval_loss': 1.1391472816467285,
#   'eval_runtime': 132.782,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 910},
#  {'epoch': 1.51, 'learning_rate': 0.0002, 'loss': 1.1431, 'step': 920},
#  {'epoch': 1.51,
#   'eval_loss': 1.1249099969863892,
#   'eval_runtime': 132.7542,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 920},
#  {'epoch': 1.53, 'learning_rate': 0.0002, 'loss': 1.0765, 'step': 930},
#  {'epoch': 1.53,
#   'eval_loss': 1.1244770288467407,
#   'eval_runtime': 132.7832,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 930},
#  {'epoch': 1.55, 'learning_rate': 0.0002, 'loss': 1.1439, 'step': 940},
#  {'epoch': 1.55,
#   'eval_loss': 1.1224828958511353,
#   'eval_runtime': 132.6311,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 940},
#  {'epoch': 1.56, 'learning_rate': 0.0002, 'loss': 1.0279, 'step': 950},
#  {'epoch': 1.56,
#   'eval_loss': 1.1232799291610718,
#   'eval_runtime': 132.64,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 950},
#  {'epoch': 1.58, 'learning_rate': 0.0002, 'loss': 0.8277, 'step': 960},
#  {'epoch': 1.58,
#   'eval_loss': 1.1280062198638916,
#   'eval_runtime': 132.6878,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 960},
#  {'epoch': 1.6, 'learning_rate': 0.0002, 'loss': 1.1022, 'step': 970},
#  {'epoch': 1.6,
#   'eval_loss': 1.1212542057037354,
#   'eval_runtime': 132.776,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 970},
#  {'epoch': 1.61, 'learning_rate': 0.0002, 'loss': 1.1104, 'step': 980},
#  {'epoch': 1.61,
#   'eval_loss': 1.1176496744155884,
#   'eval_runtime': 132.6104,
#   'eval_samples_per_second': 4.585,
#   'eval_steps_per_second': 0.573,
#   'step': 980},
#  {'epoch': 1.63, 'learning_rate': 0.0002, 'loss': 1.1038, 'step': 990},
#  {'epoch': 1.63,
#   'eval_loss': 1.1171475648880005,
#   'eval_runtime': 132.7036,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 990},
#  {'epoch': 1.64, 'learning_rate': 0.0002, 'loss': 1.0312, 'step': 1000},
#  {'epoch': 1.64,
#   'eval_loss': 1.1152278184890747,
#   'eval_runtime': 132.8546,
#   'eval_samples_per_second': 4.576,
#   'eval_steps_per_second': 0.572,
#   'step': 1000},
#  {'epoch': 1.66, 'learning_rate': 0.0002, 'loss': 0.9076, 'step': 1010},
#  {'epoch': 1.66,
#   'eval_loss': 1.1186813116073608,
#   'eval_runtime': 132.7256,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1010},
#  {'epoch': 1.68, 'learning_rate': 0.0002, 'loss': 0.9918, 'step': 1020},
#  {'epoch': 1.68,
#   'eval_loss': 1.1138666868209839,
#   'eval_runtime': 132.7406,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 1020},
#  {'epoch': 1.69, 'learning_rate': 0.0002, 'loss': 1.0603, 'step': 1030},
#  {'epoch': 1.69,
#   'eval_loss': 1.1135445833206177,
#   'eval_runtime': 132.7734,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1030},
#  {'epoch': 1.71, 'learning_rate': 0.0002, 'loss': 1.0751, 'step': 1040},
#  {'epoch': 1.71,
#   'eval_loss': 1.1089503765106201,
#   'eval_runtime': 132.8257,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 1040},
#  {'epoch': 1.73, 'learning_rate': 0.0002, 'loss': 0.9859, 'step': 1050},
#  {'epoch': 1.73,
#   'eval_loss': 1.1159539222717285,
#   'eval_runtime': 132.7442,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 1050},
#  {'epoch': 1.74, 'learning_rate': 0.0002, 'loss': 0.8843, 'step': 1060},
#  {'epoch': 1.74,
#   'eval_loss': 1.123425841331482,
#   'eval_runtime': 132.6803,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1060},
#  {'epoch': 1.76, 'learning_rate': 0.0002, 'loss': 1.108, 'step': 1070},
#  {'epoch': 1.76,
#   'eval_loss': 1.1093242168426514,
#   'eval_runtime': 132.6873,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1070},
#  {'epoch': 1.78, 'learning_rate': 0.0002, 'loss': 1.1195, 'step': 1080},
#  {'epoch': 1.78,
#   'eval_loss': 1.1065220832824707,
#   'eval_runtime': 132.7185,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1080},
#  {'epoch': 1.79, 'learning_rate': 0.0002, 'loss': 1.0611, 'step': 1090},
#  {'epoch': 1.79,
#   'eval_loss': 1.1076346635818481,
#   'eval_runtime': 132.639,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1090},
#  {'epoch': 1.81, 'learning_rate': 0.0002, 'loss': 0.9233, 'step': 1100},
#  {'epoch': 1.81,
#   'eval_loss': 1.1061954498291016,
#   'eval_runtime': 132.8057,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 1100},
#  {'epoch': 1.83, 'learning_rate': 0.0002, 'loss': 0.8789, 'step': 1110},
#  {'epoch': 1.83,
#   'eval_loss': 1.1140574216842651,
#   'eval_runtime': 132.6549,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 1110},
#  {'epoch': 1.84, 'learning_rate': 0.0002, 'loss': 1.0669, 'step': 1120},
#  {'epoch': 1.84,
#   'eval_loss': 1.1054009199142456,
#   'eval_runtime': 132.6994,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1120},
#  {'epoch': 1.86, 'learning_rate': 0.0002, 'loss': 1.1175, 'step': 1130},
#  {'epoch': 1.86,
#   'eval_loss': 1.103235125541687,
#   'eval_runtime': 132.6939,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1130},
#  {'epoch': 1.88, 'learning_rate': 0.0002, 'loss': 1.1462, 'step': 1140},
#  {'epoch': 1.88,
#   'eval_loss': 1.1037218570709229,
#   'eval_runtime': 132.7623,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1140},
#  {'epoch': 1.89, 'learning_rate': 0.0002, 'loss': 0.9641, 'step': 1150},
#  {'epoch': 1.89,
#   'eval_loss': 1.1083046197891235,
#   'eval_runtime': 132.7894,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1150},
#  {'epoch': 1.91, 'learning_rate': 0.0002, 'loss': 0.9078, 'step': 1160},
#  {'epoch': 1.91,
#   'eval_loss': 1.117952823638916,
#   'eval_runtime': 132.5742,
#   'eval_samples_per_second': 4.586,
#   'eval_steps_per_second': 0.573,
#   'step': 1160},
#  {'epoch': 1.92, 'learning_rate': 0.0002, 'loss': 1.0277, 'step': 1170},
#  {'epoch': 1.92,
#   'eval_loss': 1.0990318059921265,
#   'eval_runtime': 132.7358,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1170},
#  {'epoch': 1.94, 'learning_rate': 0.0002, 'loss': 1.0316, 'step': 1180},
#  {'epoch': 1.94,
#   'eval_loss': 1.0954947471618652,
#   'eval_runtime': 132.6456,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1180},
#  {'epoch': 1.96, 'learning_rate': 0.0002, 'loss': 1.0304, 'step': 1190},
#  {'epoch': 1.96,
#   'eval_loss': 1.0959405899047852,
#   'eval_runtime': 132.6052,
#   'eval_samples_per_second': 4.585,
#   'eval_steps_per_second': 0.573,
#   'step': 1190},
#  {'epoch': 1.97, 'learning_rate': 0.0002, 'loss': 1.058, 'step': 1200},
#  {'epoch': 1.97,
#   'eval_loss': 1.0976837873458862,
#   'eval_runtime': 132.6566,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 1200},
#  {'epoch': 1.99, 'learning_rate': 0.0002, 'loss': 0.8219, 'step': 1210},
#  {'epoch': 1.99,
#   'eval_loss': 1.1084871292114258,
#   'eval_runtime': 132.742,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 1210},
#  {'epoch': 2.01, 'learning_rate': 0.0002, 'loss': 0.9587, 'step': 1220},
#  {'epoch': 2.01,
#   'eval_loss': 1.1010624170303345,
#   'eval_runtime': 132.6857,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1220},
#  {'epoch': 2.02, 'learning_rate': 0.0002, 'loss': 0.9787, 'step': 1230},
#  {'epoch': 2.02,
#   'eval_loss': 1.1010979413986206,
#   'eval_runtime': 132.5509,
#   'eval_samples_per_second': 4.587,
#   'eval_steps_per_second': 0.573,
#   'step': 1230},
#  {'epoch': 2.04, 'learning_rate': 0.0002, 'loss': 1.0209, 'step': 1240},
#  {'epoch': 2.04,
#   'eval_loss': 1.1067944765090942,
#   'eval_runtime': 132.6324,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1240},
#  {'epoch': 2.06, 'learning_rate': 0.0002, 'loss': 0.9119, 'step': 1250},
#  {'epoch': 2.06,
#   'eval_loss': 1.1057555675506592,
#   'eval_runtime': 132.6946,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1250},
#  {'epoch': 2.07, 'learning_rate': 0.0002, 'loss': 0.819, 'step': 1260},
#  {'epoch': 2.07,
#   'eval_loss': 1.1266497373580933,
#   'eval_runtime': 132.7162,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1260},
#  {'epoch': 2.09, 'learning_rate': 0.0002, 'loss': 0.7286, 'step': 1270},
#  {'epoch': 2.09,
#   'eval_loss': 1.1367714405059814,
#   'eval_runtime': 132.7258,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1270},
#  {'epoch': 2.11, 'learning_rate': 0.0002, 'loss': 0.927, 'step': 1280},
#  {'epoch': 2.11,
#   'eval_loss': 1.104914665222168,
#   'eval_runtime': 132.7026,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1280},
#  {'epoch': 2.12, 'learning_rate': 0.0002, 'loss': 0.9502, 'step': 1290},
#  {'epoch': 2.12,
#   'eval_loss': 1.1114411354064941,
#   'eval_runtime': 132.6445,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1290},
#  {'epoch': 2.14, 'learning_rate': 0.0002, 'loss': 0.9063, 'step': 1300},
#  {'epoch': 2.14,
#   'eval_loss': 1.1144901514053345,
#   'eval_runtime': 132.7216,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1300},
#  {'epoch': 2.15, 'learning_rate': 0.0002, 'loss': 0.859, 'step': 1310},
#  {'epoch': 2.15,
#   'eval_loss': 1.1162679195404053,
#   'eval_runtime': 132.6955,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1310},
#  {'epoch': 2.17, 'learning_rate': 0.0002, 'loss': 0.7516, 'step': 1320},
#  {'epoch': 2.17,
#   'eval_loss': 1.1215627193450928,
#   'eval_runtime': 132.6832,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1320},
#  {'epoch': 2.19, 'learning_rate': 0.0002, 'loss': 0.9426, 'step': 1330},
#  {'epoch': 2.19,
#   'eval_loss': 1.0967782735824585,
#   'eval_runtime': 132.8489,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 1330},
#  {'epoch': 2.2, 'learning_rate': 0.0002, 'loss': 0.8859, 'step': 1340},
#  {'epoch': 2.2,
#   'eval_loss': 1.1050162315368652,
#   'eval_runtime': 132.6859,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1340},
#  {'epoch': 2.22, 'learning_rate': 0.0002, 'loss': 0.9666, 'step': 1350},
#  {'epoch': 2.22,
#   'eval_loss': 1.1070071458816528,
#   'eval_runtime': 132.6225,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1350},
#  {'epoch': 2.24, 'learning_rate': 0.0002, 'loss': 0.8114, 'step': 1360},
#  {'epoch': 2.24,
#   'eval_loss': 1.1118043661117554,
#   'eval_runtime': 132.6459,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1360},
#  {'epoch': 2.25, 'learning_rate': 0.0002, 'loss': 0.8746, 'step': 1370},
#  {'epoch': 2.25,
#   'eval_loss': 1.1141034364700317,
#   'eval_runtime': 132.7624,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1370},
#  {'epoch': 2.27, 'learning_rate': 0.0002, 'loss': 0.998, 'step': 1380},
#  {'epoch': 2.27,
#   'eval_loss': 1.0952609777450562,
#   'eval_runtime': 132.6985,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1380},
#  {'epoch': 2.29, 'learning_rate': 0.0002, 'loss': 0.9597, 'step': 1390},
#  {'epoch': 2.29,
#   'eval_loss': 1.096327543258667,
#   'eval_runtime': 132.7256,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1390},
#  {'epoch': 2.3, 'learning_rate': 0.0002, 'loss': 0.8991, 'step': 1400},
#  {'epoch': 2.3,
#   'eval_loss': 1.1049498319625854,
#   'eval_runtime': 132.5641,
#   'eval_samples_per_second': 4.586,
#   'eval_steps_per_second': 0.573,
#   'step': 1400},
#  {'epoch': 2.32, 'learning_rate': 0.0002, 'loss': 0.871, 'step': 1410},
#  {'epoch': 2.32,
#   'eval_loss': 1.1148086786270142,
#   'eval_runtime': 132.6407,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1410},
#  {'epoch': 2.34, 'learning_rate': 0.0002, 'loss': 0.7401, 'step': 1420},
#  {'epoch': 2.34,
#   'eval_loss': 1.1162502765655518,
#   'eval_runtime': 132.5148,
#   'eval_samples_per_second': 4.588,
#   'eval_steps_per_second': 0.574,
#   'step': 1420},
#  {'epoch': 2.35, 'learning_rate': 0.0002, 'loss': 0.9086, 'step': 1430},
#  {'epoch': 2.35,
#   'eval_loss': 1.0928354263305664,
#   'eval_runtime': 132.7359,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1430},
#  {'epoch': 2.37, 'learning_rate': 0.0002, 'loss': 0.9402, 'step': 1440},
#  {'epoch': 2.37,
#   'eval_loss': 1.0941082239151,
#   'eval_runtime': 132.6812,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1440},
#  {'epoch': 2.38, 'learning_rate': 0.0002, 'loss': 0.9398, 'step': 1450},
#  {'epoch': 2.38,
#   'eval_loss': 1.0982760190963745,
#   'eval_runtime': 132.7251,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1450},
#  {'epoch': 2.4, 'learning_rate': 0.0002, 'loss': 0.7962, 'step': 1460},
#  {'epoch': 2.4,
#   'eval_loss': 1.1036521196365356,
#   'eval_runtime': 132.6833,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1460},
#  {'epoch': 2.42, 'learning_rate': 0.0002, 'loss': 0.7581, 'step': 1470},
#  {'epoch': 2.42,
#   'eval_loss': 1.1181737184524536,
#   'eval_runtime': 132.6991,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1470},
#  {'epoch': 2.43, 'learning_rate': 0.0002, 'loss': 0.9514, 'step': 1480},
#  {'epoch': 2.43,
#   'eval_loss': 1.0937938690185547,
#   'eval_runtime': 132.8196,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 1480},
#  {'epoch': 2.45, 'learning_rate': 0.0002, 'loss': 0.9588, 'step': 1490},
#  {'epoch': 2.45,
#   'eval_loss': 1.0935032367706299,
#   'eval_runtime': 132.7652,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1490},
#  {'epoch': 2.47, 'learning_rate': 0.0002, 'loss': 0.9753, 'step': 1500},
#  {'epoch': 2.47,
#   'eval_loss': 1.095639944076538,
#   'eval_runtime': 132.7773,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1500},
#  {'epoch': 2.48, 'learning_rate': 0.0002, 'loss': 0.8748, 'step': 1510},
#  {'epoch': 2.48,
#   'eval_loss': 1.0944581031799316,
#   'eval_runtime': 132.7603,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1510},
#  {'epoch': 2.5, 'learning_rate': 0.0002, 'loss': 0.8047, 'step': 1520},
#  {'epoch': 2.5,
#   'eval_loss': 1.1057178974151611,
#   'eval_runtime': 132.7219,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1520},
#  {'epoch': 2.52, 'learning_rate': 0.0002, 'loss': 0.9293, 'step': 1530},
#  {'epoch': 2.52,
#   'eval_loss': 1.0894333124160767,
#   'eval_runtime': 132.6598,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 1530},
#  {'epoch': 2.53, 'learning_rate': 0.0002, 'loss': 0.9637, 'step': 1540},
#  {'epoch': 2.53,
#   'eval_loss': 1.0873198509216309,
#   'eval_runtime': 132.6429,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1540},
#  {'epoch': 2.55, 'learning_rate': 0.0002, 'loss': 0.9474, 'step': 1550},
#  {'epoch': 2.55,
#   'eval_loss': 1.0866615772247314,
#   'eval_runtime': 132.9426,
#   'eval_samples_per_second': 4.573,
#   'eval_steps_per_second': 0.572,
#   'step': 1550},
#  {'epoch': 2.57, 'learning_rate': 0.0002, 'loss': 0.8085, 'step': 1560},
#  {'epoch': 2.57,
#   'eval_loss': 1.0976207256317139,
#   'eval_runtime': 132.8118,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 1560},
#  {'epoch': 2.58, 'learning_rate': 0.0002, 'loss': 0.7722, 'step': 1570},
#  {'epoch': 2.58,
#   'eval_loss': 1.1014536619186401,
#   'eval_runtime': 132.7836,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1570},
#  {'epoch': 2.6, 'learning_rate': 0.0002, 'loss': 0.9301, 'step': 1580},
#  {'epoch': 2.6,
#   'eval_loss': 1.0828120708465576,
#   'eval_runtime': 132.7662,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1580},
#  {'epoch': 2.62, 'learning_rate': 0.0002, 'loss': 0.9466, 'step': 1590},
#  {'epoch': 2.62,
#   'eval_loss': 1.0830761194229126,
#   'eval_runtime': 132.7515,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1590},
#  {'epoch': 2.63, 'learning_rate': 0.0002, 'loss': 0.9009, 'step': 1600},
#  {'epoch': 2.63,
#   'eval_loss': 1.0930700302124023,
#   'eval_runtime': 132.7177,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1600},
#  {'epoch': 2.65, 'learning_rate': 0.0002, 'loss': 0.8125, 'step': 1610},
#  {'epoch': 2.65,
#   'eval_loss': 1.1000876426696777,
#   'eval_runtime': 132.7822,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1610},
#  {'epoch': 2.66, 'learning_rate': 0.0002, 'loss': 0.8098, 'step': 1620},
#  {'epoch': 2.66,
#   'eval_loss': 1.096262812614441,
#   'eval_runtime': 132.716,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1620},
#  {'epoch': 2.68, 'learning_rate': 0.0002, 'loss': 0.9344, 'step': 1630},
#  {'epoch': 2.68,
#   'eval_loss': 1.0786223411560059,
#   'eval_runtime': 132.7672,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1630},
#  {'epoch': 2.7, 'learning_rate': 0.0002, 'loss': 0.9793, 'step': 1640},
#  {'epoch': 2.7,
#   'eval_loss': 1.077808141708374,
#   'eval_runtime': 132.6242,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1640},
#  {'epoch': 2.71, 'learning_rate': 0.0002, 'loss': 0.9771, 'step': 1650},
#  {'epoch': 2.71,
#   'eval_loss': 1.0918837785720825,
#   'eval_runtime': 132.7562,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1650},
#  {'epoch': 2.73, 'learning_rate': 0.0002, 'loss': 0.7475, 'step': 1660},
#  {'epoch': 2.73,
#   'eval_loss': 1.0977481603622437,
#   'eval_runtime': 132.6504,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 1660},
#  {'epoch': 2.75, 'learning_rate': 0.0002, 'loss': 0.7498, 'step': 1670},
#  {'epoch': 2.75,
#   'eval_loss': 1.0956027507781982,
#   'eval_runtime': 132.7503,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 1670},
#  {'epoch': 2.76, 'learning_rate': 0.0002, 'loss': 0.9693, 'step': 1680},
#  {'epoch': 2.76,
#   'eval_loss': 1.0786774158477783,
#   'eval_runtime': 132.7041,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1680},
#  {'epoch': 2.78, 'learning_rate': 0.0002, 'loss': 0.9575, 'step': 1690},
#  {'epoch': 2.78,
#   'eval_loss': 1.0757008790969849,
#   'eval_runtime': 132.7643,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1690},
#  {'epoch': 2.8, 'learning_rate': 0.0002, 'loss': 0.8757, 'step': 1700},
#  {'epoch': 2.8,
#   'eval_loss': 1.0822430849075317,
#   'eval_runtime': 132.7879,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1700},
#  {'epoch': 2.81, 'learning_rate': 0.0002, 'loss': 0.8302, 'step': 1710},
#  {'epoch': 2.81,
#   'eval_loss': 1.0890394449234009,
#   'eval_runtime': 132.6772,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 1710},
#  {'epoch': 2.83, 'learning_rate': 0.0002, 'loss': 0.7099, 'step': 1720},
#  {'epoch': 2.83,
#   'eval_loss': 1.0944099426269531,
#   'eval_runtime': 132.646,
#   'eval_samples_per_second': 4.584,
#   'eval_steps_per_second': 0.573,
#   'step': 1720},
#  {'epoch': 2.85, 'learning_rate': 0.0002, 'loss': 0.9333, 'step': 1730},
#  {'epoch': 2.85,
#   'eval_loss': 1.0802371501922607,
#   'eval_runtime': 132.7052,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1730},
#  {'epoch': 2.86, 'learning_rate': 0.0002, 'loss': 0.9396, 'step': 1740},
#  {'epoch': 2.86,
#   'eval_loss': 1.0795727968215942,
#   'eval_runtime': 132.7459,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 1740},
#  {'epoch': 2.88, 'learning_rate': 0.0002, 'loss': 0.9794, 'step': 1750},
#  {'epoch': 2.88,
#   'eval_loss': 1.078001618385315,
#   'eval_runtime': 132.7633,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1750},
#  {'epoch': 2.89, 'learning_rate': 0.0002, 'loss': 0.7678, 'step': 1760},
#  {'epoch': 2.89,
#   'eval_loss': 1.0830857753753662,
#   'eval_runtime': 132.7801,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1760},
#  {'epoch': 2.91, 'learning_rate': 0.0002, 'loss': 0.85, 'step': 1770},
#  {'epoch': 2.91,
#   'eval_loss': 1.0816755294799805,
#   'eval_runtime': 132.7774,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1770},
#  {'epoch': 2.93, 'learning_rate': 0.0002, 'loss': 1.0029, 'step': 1780},
#  {'epoch': 2.93,
#   'eval_loss': 1.070784568786621,
#   'eval_runtime': 132.72,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1780},
#  {'epoch': 2.94, 'learning_rate': 0.0002, 'loss': 0.9569, 'step': 1790},
#  {'epoch': 2.94,
#   'eval_loss': 1.071345329284668,
#   'eval_runtime': 132.8133,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 1790},
#  {'epoch': 2.96, 'learning_rate': 0.0002, 'loss': 0.8589, 'step': 1800},
#  {'epoch': 2.96,
#   'eval_loss': 1.0896596908569336,
#   'eval_runtime': 132.6737,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 1800},
#  {'epoch': 2.98, 'learning_rate': 0.0002, 'loss': 0.735, 'step': 1810},
#  {'epoch': 2.98,
#   'eval_loss': 1.0895066261291504,
#   'eval_runtime': 132.7877,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1810},
#  {'epoch': 2.99, 'learning_rate': 0.0002, 'loss': 0.7746, 'step': 1820},
#  {'epoch': 2.99,
#   'eval_loss': 1.088636040687561,
#   'eval_runtime': 132.7844,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1820},
#  {'epoch': 3.01, 'learning_rate': 0.0002, 'loss': 0.8142, 'step': 1830},
#  {'epoch': 3.01,
#   'eval_loss': 1.078157663345337,
#   'eval_runtime': 132.7966,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 1830},
#  {'epoch': 3.03, 'learning_rate': 0.0002, 'loss': 0.8422, 'step': 1840},
#  {'epoch': 3.03,
#   'eval_loss': 1.092179775238037,
#   'eval_runtime': 132.7724,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1840},
#  {'epoch': 3.04, 'learning_rate': 0.0002, 'loss': 0.7891, 'step': 1850},
#  {'epoch': 3.04,
#   'eval_loss': 1.1054855585098267,
#   'eval_runtime': 132.7812,
#   'eval_samples_per_second': 4.579,
#   'eval_steps_per_second': 0.572,
#   'step': 1850},
#  {'epoch': 3.06, 'learning_rate': 0.0002, 'loss': 0.7758, 'step': 1860},
#  {'epoch': 3.06,
#   'eval_loss': 1.138136863708496,
#   'eval_runtime': 132.7174,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1860},
#  {'epoch': 3.08, 'learning_rate': 0.0002, 'loss': 0.6216, 'step': 1870},
#  {'epoch': 3.08,
#   'eval_loss': 1.16497802734375,
#   'eval_runtime': 132.751,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.573,
#   'step': 1870},
#  {'epoch': 3.09, 'learning_rate': 0.0002, 'loss': 0.742, 'step': 1880},
#  {'epoch': 3.09,
#   'eval_loss': 1.1194138526916504,
#   'eval_runtime': 132.7312,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1880},
#  {'epoch': 3.11, 'learning_rate': 0.0002, 'loss': 0.8656, 'step': 1890},
#  {'epoch': 3.11,
#   'eval_loss': 1.0778790712356567,
#   'eval_runtime': 132.7542,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1890},
#  {'epoch': 3.12, 'learning_rate': 0.0002, 'loss': 0.8227, 'step': 1900},
#  {'epoch': 3.12,
#   'eval_loss': 1.1006332635879517,
#   'eval_runtime': 132.7635,
#   'eval_samples_per_second': 4.58,
#   'eval_steps_per_second': 0.572,
#   'step': 1900},
#  {'epoch': 3.14, 'learning_rate': 0.0002, 'loss': 0.7331, 'step': 1910},
#  {'epoch': 3.14,
#   'eval_loss': 1.1315118074417114,
#   'eval_runtime': 132.8165,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 1910},
#  {'epoch': 3.16, 'learning_rate': 0.0002, 'loss': 0.6218, 'step': 1920},
#  {'epoch': 3.16,
#   'eval_loss': 1.156267523765564,
#   'eval_runtime': 132.6962,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1920},
#  {'epoch': 3.17, 'learning_rate': 0.0002, 'loss': 0.7275, 'step': 1930},
#  {'epoch': 3.17,
#   'eval_loss': 1.1198663711547852,
#   'eval_runtime': 132.8514,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 1930},
#  {'epoch': 3.19, 'learning_rate': 0.0002, 'loss': 0.8357, 'step': 1940},
#  {'epoch': 3.19,
#   'eval_loss': 1.0807762145996094,
#   'eval_runtime': 132.6919,
#   'eval_samples_per_second': 4.582,
#   'eval_steps_per_second': 0.573,
#   'step': 1940},
#  {'epoch': 3.21, 'learning_rate': 0.0002, 'loss': 0.8037, 'step': 1950},
#  {'epoch': 3.21,
#   'eval_loss': 1.091575264930725,
#   'eval_runtime': 132.8249,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 1950},
#  {'epoch': 3.22, 'learning_rate': 0.0002, 'loss': 0.7181, 'step': 1960},
#  {'epoch': 3.22,
#   'eval_loss': 1.117814064025879,
#   'eval_runtime': 132.7141,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1960},
#  {'epoch': 3.24, 'learning_rate': 0.0002, 'loss': 0.6082, 'step': 1970},
#  {'epoch': 3.24,
#   'eval_loss': 1.1371183395385742,
#   'eval_runtime': 132.7096,
#   'eval_samples_per_second': 4.581,
#   'eval_steps_per_second': 0.573,
#   'step': 1970},
#  {'epoch': 3.26, 'learning_rate': 0.0002, 'loss': 0.7285, 'step': 1980},
#  {'epoch': 3.26,
#   'eval_loss': 1.1225450038909912,
#   'eval_runtime': 132.6576,
#   'eval_samples_per_second': 4.583,
#   'eval_steps_per_second': 0.573,
#   'step': 1980},
#  {'epoch': 3.27, 'learning_rate': 0.0002, 'loss': 0.8416, 'step': 1990},
#  {'epoch': 3.27,
#   'eval_loss': 1.0871760845184326,
#   'eval_runtime': 132.8321,
#   'eval_samples_per_second': 4.577,
#   'eval_steps_per_second': 0.572,
#   'step': 1990},
#  {'epoch': 3.29, 'learning_rate': 0.0002, 'loss': 0.798, 'step': 2000},
#  {'epoch': 3.29,
#   'eval_loss': 1.093834638595581,
#   'eval_runtime': 132.8166,
#   'eval_samples_per_second': 4.578,
#   'eval_steps_per_second': 0.572,
#   'step': 2000},
#  {'epoch': 3.31, 'learning_rate': 0.0002, 'loss': 0.7323, 'step': 2010},
#  {'epoch': 3.31,
#   'eval_loss': 1.1233410835266113,
#   'eval_runtime': 132.8713,
#   'eval_samples_per_second': 4.576,
#   'eval_steps_per_second': 0.572,
#   'step': 2010},
#  {'epoch': 3.32, 'learning_rate': 0.0002, 'loss': 0.6937, 'step': 2020},
#  {'epoch': 3.32,
#   'eval_loss': 1.1446715593338013,
# ...
#  {'eval_loss': 0.519197940826416,
#   'eval_runtime': 125.5916,
#   'eval_samples_per_second': 4.841,
#   'eval_steps_per_second': 0.605,
#   'epoch': 7.14,
#   'step': 4340},
#  {'loss': 0.3468, 'learning_rate': 0.0002, 'epoch': 7.15, 'step': 4350},
#  {'eval_loss': 0.5249990224838257,
#   'eval_runtime': 125.4924,
#   'eval_samples_per_second': 4.845,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.15,
#   'step': 4350},
#  {'loss': 0.5256, 'learning_rate': 0.0002, 'epoch': 7.17, 'step': 4360},
#  {'eval_loss': 0.5318189859390259,
#   'eval_runtime': 125.4549,
#   'eval_samples_per_second': 4.846,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.17,
#   'step': 4360},
#  {'loss': 0.5966, 'learning_rate': 0.0002, 'epoch': 7.19, 'step': 4370},
#  {'eval_loss': 0.5225339531898499,
#   'eval_runtime': 125.4018,
#   'eval_samples_per_second': 4.848,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.19,
#   'step': 4370},
#  {'loss': 0.5445, 'learning_rate': 0.0002, 'epoch': 7.2, 'step': 4380},
#  {'eval_loss': 0.5202598571777344,
#   'eval_runtime': 125.5467,
#   'eval_samples_per_second': 4.843,
#   'eval_steps_per_second': 0.605,
#   'epoch': 7.2,
#   'step': 4380},
#  {'loss': 0.5106, 'learning_rate': 0.0002, 'epoch': 7.22, 'step': 4390},
#  {'eval_loss': 0.5208029747009277,
#   'eval_runtime': 125.463,
#   'eval_samples_per_second': 4.846,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.22,
#   'step': 4390},
#  {'loss': 0.4877, 'learning_rate': 0.0002, 'epoch': 7.24, 'step': 4400},
#  {'eval_loss': 0.5280450582504272,
#   'eval_runtime': 125.5341,
#   'eval_samples_per_second': 4.843,
#   'eval_steps_per_second': 0.605,
#   'epoch': 7.24,
#   'step': 4400},
#  {'loss': 0.4831, 'learning_rate': 0.0002, 'epoch': 7.25, 'step': 4410},
#  {'eval_loss': 0.53281170129776,
#   'eval_runtime': 125.4314,
#   'eval_samples_per_second': 4.847,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.25,
#   'step': 4410},
#  {'loss': 0.6481, 'learning_rate': 0.0002, 'epoch': 7.27, 'step': 4420},
#  {'eval_loss': 0.5244688391685486,
#   'eval_runtime': 125.5419,
#   'eval_samples_per_second': 4.843,
#   'eval_steps_per_second': 0.605,
#   'epoch': 7.27,
#   'step': 4420},
#  {'loss': 0.5507, 'learning_rate': 0.0002, 'epoch': 7.29, 'step': 4430},
#  {'eval_loss': 0.5255396962165833,
#   'eval_runtime': 125.509,
#   'eval_samples_per_second': 4.844,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.29,
#   'step': 4430},
#  {'loss': 0.5777, 'learning_rate': 0.0002, 'epoch': 7.3, 'step': 4440},
#  {'eval_loss': 0.5273716449737549,
#   'eval_runtime': 125.4405,
#   'eval_samples_per_second': 4.847,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.3,
#   'step': 4440},
#  {'loss': 0.5531, 'learning_rate': 0.0002, 'epoch': 7.32, 'step': 4450},
#  {'eval_loss': 0.539493978023529,
#   'eval_runtime': 125.3106,
#   'eval_samples_per_second': 4.852,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.32,
#   'step': 4450},
#  {'loss': 0.6581, 'learning_rate': 0.0002, 'epoch': 7.34, 'step': 4460},
#  {'eval_loss': 0.542065441608429,
#   'eval_runtime': 125.0938,
#   'eval_samples_per_second': 4.86,
#   'eval_steps_per_second': 0.608,
#   'epoch': 7.34,
#   'step': 4460},
#  {'loss': 0.6538, 'learning_rate': 0.0002, 'epoch': 7.35, 'step': 4470},
#  {'eval_loss': 0.5338053107261658,
#   'eval_runtime': 125.2212,
#   'eval_samples_per_second': 4.855,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.35,
#   'step': 4470},
#  {'loss': 0.4914, 'learning_rate': 0.0002, 'epoch': 7.37, 'step': 4480},
#  {'eval_loss': 0.5296401381492615,
#   'eval_runtime': 125.1869,
#   'eval_samples_per_second': 4.857,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.37,
#   'step': 4480},
#  {'loss': 0.496, 'learning_rate': 0.0002, 'epoch': 7.38, 'step': 4490},
#  {'eval_loss': 0.5343639254570007,
#   'eval_runtime': 125.1495,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.38,
#   'step': 4490},
#  {'loss': 0.4647, 'learning_rate': 0.0002, 'epoch': 7.4, 'step': 4500},
#  {'eval_loss': 0.5448737144470215,
#   'eval_runtime': 125.3324,
#   'eval_samples_per_second': 4.851,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.4,
#   'step': 4500},
#  {'loss': 0.5873, 'learning_rate': 0.0002, 'epoch': 7.42, 'step': 4510},
#  {'eval_loss': 0.5462508797645569,
#   'eval_runtime': 125.1871,
#   'eval_samples_per_second': 4.857,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.42,
#   'step': 4510},
#  {'loss': 0.6186, 'learning_rate': 0.0002, 'epoch': 7.43, 'step': 4520},
#  {'eval_loss': 0.5334372520446777,
#   'eval_runtime': 125.2693,
#   'eval_samples_per_second': 4.854,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.43,
#   'step': 4520},
#  {'loss': 0.4743, 'learning_rate': 0.0002, 'epoch': 7.45, 'step': 4530},
#  {'eval_loss': 0.5308681726455688,
#   'eval_runtime': 125.1834,
#   'eval_samples_per_second': 4.857,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.45,
#   'step': 4530},
#  {'loss': 0.58, 'learning_rate': 0.0002, 'epoch': 7.47, 'step': 4540},
#  {'eval_loss': 0.5284357070922852,
#   'eval_runtime': 125.2748,
#   'eval_samples_per_second': 4.853,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.47,
#   'step': 4540},
#  {'loss': 0.4734, 'learning_rate': 0.0002, 'epoch': 7.48, 'step': 4550},
#  {'eval_loss': 0.533613920211792,
#   'eval_runtime': 125.4755,
#   'eval_samples_per_second': 4.846,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.48,
#   'step': 4550},
#  {'loss': 0.5431, 'learning_rate': 0.0002, 'epoch': 7.5, 'step': 4560},
#  {'eval_loss': 0.5429166555404663,
#   'eval_runtime': 125.3283,
#   'eval_samples_per_second': 4.851,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.5,
#   'step': 4560},
#  {'loss': 0.5226, 'learning_rate': 0.0002, 'epoch': 7.52, 'step': 4570},
#  {'eval_loss': 0.5347535610198975,
#   'eval_runtime': 125.3459,
#   'eval_samples_per_second': 4.851,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.52,
#   'step': 4570},
#  {'loss': 0.5137, 'learning_rate': 0.0002, 'epoch': 7.53, 'step': 4580},
#  {'eval_loss': 0.5347274541854858,
#   'eval_runtime': 125.2721,
#   'eval_samples_per_second': 4.853,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.53,
#   'step': 4580},
#  {'loss': 0.5209, 'learning_rate': 0.0002, 'epoch': 7.55, 'step': 4590},
#  {'eval_loss': 0.5355445742607117,
#   'eval_runtime': 125.275,
#   'eval_samples_per_second': 4.853,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.55,
#   'step': 4590},
#  {'loss': 0.5089, 'learning_rate': 0.0002, 'epoch': 7.57, 'step': 4600},
#  {'eval_loss': 0.5433118939399719,
#   'eval_runtime': 125.2722,
#   'eval_samples_per_second': 4.853,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.57,
#   'step': 4600},
#  {'loss': 0.4273, 'learning_rate': 0.0002, 'epoch': 7.58, 'step': 4610},
#  {'eval_loss': 0.551539957523346,
#   'eval_runtime': 125.1059,
#   'eval_samples_per_second': 4.86,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.58,
#   'step': 4610},
#  {'loss': 0.6244, 'learning_rate': 0.0002, 'epoch': 7.6, 'step': 4620},
#  {'eval_loss': 0.5418372750282288,
#   'eval_runtime': 125.1354,
#   'eval_samples_per_second': 4.859,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.6,
#   'step': 4620},
#  {'loss': 0.4776, 'learning_rate': 0.0002, 'epoch': 7.62, 'step': 4630},
#  {'eval_loss': 0.5395296216011047,
#   'eval_runtime': 125.1049,
#   'eval_samples_per_second': 4.86,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.62,
#   'step': 4630},
#  {'loss': 0.5748, 'learning_rate': 0.0002, 'epoch': 7.63, 'step': 4640},
#  {'eval_loss': 0.5378355383872986,
#   'eval_runtime': 125.2977,
#   'eval_samples_per_second': 4.852,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.63,
#   'step': 4640},
#  {'loss': 0.4667, 'learning_rate': 0.0002, 'epoch': 7.65, 'step': 4650},
#  {'eval_loss': 0.5444140434265137,
#   'eval_runtime': 125.3629,
#   'eval_samples_per_second': 4.85,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.65,
#   'step': 4650},
#  {'loss': 0.5746, 'learning_rate': 0.0002, 'epoch': 7.66, 'step': 4660},
#  {'eval_loss': 0.5497122406959534,
#   'eval_runtime': 125.1451,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.66,
#   'step': 4660},
#  {'loss': 0.5417, 'learning_rate': 0.0002, 'epoch': 7.68, 'step': 4670},
#  {'eval_loss': 0.5431028008460999,
#   'eval_runtime': 125.4847,
#   'eval_samples_per_second': 4.845,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.68,
#   'step': 4670},
#  {'loss': 0.5477, 'learning_rate': 0.0002, 'epoch': 7.7, 'step': 4680},
#  {'eval_loss': 0.5430155396461487,
#   'eval_runtime': 125.2113,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.7,
#   'step': 4680},
#  {'loss': 0.5523, 'learning_rate': 0.0002, 'epoch': 7.71, 'step': 4690},
#  {'eval_loss': 0.5417162179946899,
#   'eval_runtime': 125.384,
#   'eval_samples_per_second': 4.849,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.71,
#   'step': 4690},
#  {'loss': 0.4697, 'learning_rate': 0.0002, 'epoch': 7.73, 'step': 4700},
#  {'eval_loss': 0.5492031574249268,
#   'eval_runtime': 125.2084,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.73,
#   'step': 4700},
#  {'loss': 0.6319, 'learning_rate': 0.0002, 'epoch': 7.75, 'step': 4710},
#  {'eval_loss': 0.5532697439193726,
#   'eval_runtime': 125.2857,
#   'eval_samples_per_second': 4.853,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.75,
#   'step': 4710},
#  {'loss': 0.6074, 'learning_rate': 0.0002, 'epoch': 7.76, 'step': 4720},
#  {'eval_loss': 0.5487094521522522,
#   'eval_runtime': 125.1565,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.76,
#   'step': 4720},
#  {'loss': 0.4858, 'learning_rate': 0.0002, 'epoch': 7.78, 'step': 4730},
#  {'eval_loss': 0.5436955690383911,
#   'eval_runtime': 125.0925,
#   'eval_samples_per_second': 4.86,
#   'eval_steps_per_second': 0.608,
#   'epoch': 7.78,
#   'step': 4730},
#  {'loss': 0.4396, 'learning_rate': 0.0002, 'epoch': 7.8, 'step': 4740},
#  {'eval_loss': 0.5414748191833496,
#   'eval_runtime': 125.3135,
#   'eval_samples_per_second': 4.852,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.8,
#   'step': 4740},
#  {'loss': 0.3668, 'learning_rate': 0.0002, 'epoch': 7.81, 'step': 4750},
#  {'eval_loss': 0.5474464893341064,
#   'eval_runtime': 125.3523,
#   'eval_samples_per_second': 4.85,
#   'eval_steps_per_second': 0.606,
#   'epoch': 7.81,
#   'step': 4750},
#  {'loss': 0.5153, 'learning_rate': 0.0002, 'epoch': 7.83, 'step': 4760},
#  {'eval_loss': 0.5536251068115234,
#   'eval_runtime': 125.526,
#   'eval_samples_per_second': 4.844,
#   'eval_steps_per_second': 0.605,
#   'epoch': 7.83,
#   'step': 4760},
#  {'loss': 0.6231, 'learning_rate': 0.0002, 'epoch': 7.85, 'step': 4770},
#  {'eval_loss': 0.5455636382102966,
#   'eval_runtime': 125.1466,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.85,
#   'step': 4770},
#  {'loss': 0.5715, 'learning_rate': 0.0002, 'epoch': 7.86, 'step': 4780},
#  {'eval_loss': 0.5446150302886963,
#   'eval_runtime': 125.1574,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.86,
#   'step': 4780},
#  {'loss': 0.5312, 'learning_rate': 0.0002, 'epoch': 7.88, 'step': 4790},
#  {'eval_loss': 0.542695939540863,
#   'eval_runtime': 125.2159,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.88,
#   'step': 4790},
#  {'loss': 0.442, 'learning_rate': 0.0002, 'epoch': 7.89, 'step': 4800},
#  {'eval_loss': 0.5505543351173401,
#   'eval_runtime': 125.1447,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.89,
#   'step': 4800},
#  {'loss': 0.4535, 'learning_rate': 0.0002, 'epoch': 7.91, 'step': 4810},
#  {'eval_loss': 0.5608150959014893,
#   'eval_runtime': 125.1658,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.91,
#   'step': 4810},
#  {'loss': 0.5538, 'learning_rate': 0.0002, 'epoch': 7.93, 'step': 4820},
#  {'eval_loss': 0.5539807081222534,
#   'eval_runtime': 125.2056,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.93,
#   'step': 4820},
#  {'loss': 0.49, 'learning_rate': 0.0002, 'epoch': 7.94, 'step': 4830},
#  {'eval_loss': 0.5505404472351074,
#   'eval_runtime': 125.2205,
#   'eval_samples_per_second': 4.855,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.94,
#   'step': 4830},
#  {'loss': 0.5781, 'learning_rate': 0.0002, 'epoch': 7.96, 'step': 4840},
#  {'eval_loss': 0.5460034608840942,
#   'eval_runtime': 125.1624,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.96,
#   'step': 4840},
#  {'loss': 0.5868, 'learning_rate': 0.0002, 'epoch': 7.98, 'step': 4850},
#  {'eval_loss': 0.5556379556655884,
#   'eval_runtime': 125.2028,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.98,
#   'step': 4850},
#  {'loss': 0.4376, 'learning_rate': 0.0002, 'epoch': 7.99, 'step': 4860},
#  {'eval_loss': 0.5546275973320007,
#   'eval_runtime': 125.3077,
#   'eval_samples_per_second': 4.852,
#   'eval_steps_per_second': 0.607,
#   'epoch': 7.99,
#   'step': 4860},
#  {'loss': 0.4448, 'learning_rate': 0.0002, 'epoch': 8.01, 'step': 4870},
#  {'eval_loss': 0.5614809989929199,
#   'eval_runtime': 125.1613,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.01,
#   'step': 4870},
#  {'loss': 0.3729, 'learning_rate': 0.0002, 'epoch': 8.03, 'step': 4880},
#  {'eval_loss': 0.5641845464706421,
#   'eval_runtime': 125.1515,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.03,
#   'step': 4880},
#  {'loss': 0.4309, 'learning_rate': 0.0002, 'epoch': 8.04, 'step': 4890},
#  {'eval_loss': 0.5571524500846863,
#   'eval_runtime': 125.1997,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.04,
#   'step': 4890},
#  {'loss': 0.3815, 'learning_rate': 0.0002, 'epoch': 8.06, 'step': 4900},
#  {'eval_loss': 0.5556296110153198,
#   'eval_runtime': 125.1941,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.06,
#   'step': 4900},
#  {'loss': 0.3783, 'learning_rate': 0.0002, 'epoch': 8.08, 'step': 4910},
#  {'eval_loss': 0.5703469514846802,
#   'eval_runtime': 125.1596,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.08,
#   'step': 4910},
#  {'loss': 0.428, 'learning_rate': 0.0002, 'epoch': 8.09, 'step': 4920},
#  {'eval_loss': 0.5715516805648804,
#   'eval_runtime': 125.1553,
#   'eval_samples_per_second': 4.858,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.09,
#   'step': 4920},
#  {'loss': 0.4442, 'learning_rate': 0.0002, 'epoch': 8.11, 'step': 4930},
#  {'eval_loss': 0.5596056580543518,
#   'eval_runtime': 125.2056,
#   'eval_samples_per_second': 4.856,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.11,
#   'step': 4930},
#  {'loss': 0.4181, 'learning_rate': 0.0002, 'epoch': 8.12, 'step': 4940},
#  {'eval_loss': 0.5650363564491272,
#   'eval_runtime': 125.3054,
#   'eval_samples_per_second': 4.852,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.12,
#   'step': 4940},
#  {'loss': 0.4129, 'learning_rate': 0.0002, 'epoch': 8.14, 'step': 4950},
#  {'eval_loss': 0.5623006820678711,
#   'eval_runtime': 125.2862,
#   'eval_samples_per_second': 4.853,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.14,
#   'step': 4950},
#  {'loss': 0.3587, 'learning_rate': 0.0002, 'epoch': 8.16, 'step': 4960},
#  {'eval_loss': 0.5717654228210449,
#   'eval_runtime': 125.2976,
#   'eval_samples_per_second': 4.852,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.16,
#   'step': 4960},
#  {'loss': 0.505, 'learning_rate': 0.0002, 'epoch': 8.17, 'step': 4970},
#  {'eval_loss': 0.5676636695861816,
#   'eval_runtime': 125.1373,
#   'eval_samples_per_second': 4.859,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.17,
#   'step': 4970},
#  {'loss': 0.4906, 'learning_rate': 0.0002, 'epoch': 8.19, 'step': 4980},
#  {'eval_loss': 0.5581210851669312,
#   'eval_runtime': 125.1403,
#   'eval_samples_per_second': 4.859,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.19,
#   'step': 4980},
#  {'loss': 0.3786, 'learning_rate': 0.0002, 'epoch': 8.21, 'step': 4990},
#  {'eval_loss': 0.5605869889259338,
#   'eval_runtime': 125.2928,
#   'eval_samples_per_second': 4.853,
#   'eval_steps_per_second': 0.607,
#   'epoch': 8.21,
#   'step': 4990},
#  {'loss': 0.4982, 'learning_rate': 0.0002, 'epoch': 8.22, 'step': 5000},
#  {'eval_loss': 0.559241533279419,
#   'eval_runtime': 125.316,
#   'eval_samples_per_second': 4.852,
#   'eval_steps_per_second': 0.606,
#   'epoch': 8.22,
#   'step': 5000},
#  ...]

# %%
def get_tuning_loss_plot(log_hist, graph_name):
    epoches, train_loss, val_loss = [], [], []
    for i in range(len(log_hist)//2):
        epoches.append(log_hist[2*i]['epoch'])
        train_loss.append(log_hist[2*i]['loss'])
        val_loss.append(log_hist[2*i+1]['eval_loss'])

    plt.plot(epoches, train_loss, label = "train loss") 
    plt.plot(epoches, val_loss, label = "validation loss") 
    plt.legend()
    plt.title("Model fine tune loss")
    plt.xlabel("epoches")
    plt.ylabel("loss")
    plt.savefig(f"{graph_name}_tuning_loss.png")
    plt.show()

# %%
get_tuning_loss_plot(trainer.state.log_history, refined_model)
